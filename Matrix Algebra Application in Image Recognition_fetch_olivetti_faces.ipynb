# %% [markdown]
# # Matrix Algebra Application in Image Recognition, fetch_olivetti_faces

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /Users/TJHsiao/scikit_learn_data

# %%
faces.images[0,:,:]
faces.images.shape
# Out:
# (400, 64, 64)

# %%
plt.imshow(faces.images[0,:,:], cmap=plt.cm.gray)

# %%
plt.imshow(faces.images[10,:,:], cmap=plt.cm.gray)

# %%
faces.images[0,:,:].flatten()
# Out:
# array([0.30991736, 0.3677686 , 0.41735536, ..., 0.15289256, 0.16115703,
#        0.1570248 ], dtype=float32)

# %%
faces.data
# Out:
# array([[0.30991736, 0.3677686 , 0.41735536, ..., 0.15289256, 0.16115703,
#         0.1570248 ],
#        [0.45454547, 0.47107437, 0.5123967 , ..., 0.15289256, 0.15289256,
#         0.15289256],
#        [0.3181818 , 0.40082645, 0.49173555, ..., 0.14049587, 0.14876033,
#         0.15289256],
#        ...,
#        [0.5       , 0.53305787, 0.607438  , ..., 0.17768595, 0.14876033,
#         0.19008264],
#        [0.21487603, 0.21900827, 0.21900827, ..., 0.57438016, 0.59090906,
#         0.60330576],
#        [0.5165289 , 0.46280992, 0.28099173, ..., 0.35950413, 0.3553719 ,
#         0.38429752]], dtype=float32)

# %%
X=faces.data.copy()
plt.imshow(X[0,:].reshape(64,64), cmap=plt.cm.gray)

# %%
n,p = X.shape
print(n,p)
# Out:
# 400 4096

# %%
means=np.mean(X, axis=0)
sds=np.std(X, axis =0)
print(means)
print(sds)
# Out:
# [0.40013435 0.43423545 0.4762809  ... 0.32141536 0.3136469  0.31045464]
# [0.18046872 0.18926673 0.19449872 ... 0.18760698 0.18338676 0.1804086 ]

# %%
Xstand=(X-means)/sds

# %%
Xstand
# Out:
# array([[-0.49990377, -0.35118094, -0.30296108, ..., -0.8982758 ,
#         -0.8315207 , -0.85045743],
#        [ 0.30149886,  0.19464023,  0.18568654, ..., -0.8982758 ,
#         -0.8765865 , -0.87336236],
#        [-0.4541094 , -0.17651808,  0.07945888, ..., -0.9643538 ,
#         -0.8991193 , -0.87336236],
#        ...,
#        [ 0.55336815,  0.52213305,  0.67433417, ..., -0.7661198 ,
#         -0.8991193 , -0.66721874],
#        [-1.0265398 , -1.1371634 , -1.3227472 , ...,  1.3483763 ,
#          1.5118984 ,  1.6232659 ],
#        [ 0.6449569 ,  0.15097459, -1.004064  , ...,  0.20302427,
#          0.2275245 ,  0.40930912]], dtype=float32)

# %%
plt.imshow(means.reshape(64, 64), cmap=plt.cm.gray)

# %%
plt.imshow(sds.reshape(64, 64), cmap=plt.cm.gray)

# %%
XTX= X.T @ X
XTX.shape
# Out:
# (4096, 4096)

# %% [markdown]
# Part 2: In groups
# (Discussion questions are in bold)
# What are the dimensions of X? What are n and p? (X is the data matrix faces.data)
# Standardize X into a new matrix
# Compute the mean of each column and store this as a vector.
# Compute the standard deviation of each column and store these as a vector.
# Create a standardized version of X: subtract the mean from each column, and divide each column by its standard deviation.
# Pick an image (between 0 and 399) from the original X and plot it.
# Plot the same image from the new standardized X. How are these images different? Why do you think they’re different?
# Reshape the mean vector from (2) and plot it. What does this image represent?
# Reshape the standard deviation vector from (2) and plot it. What does this image represent?
# Form the square matrix X’X. What are the dimensions of this matrix?
# Without trying to calculate it, will this matrix (X’X) be invertible? Why or why not?
# Compute the eigen decomposition of X’X. (This will take a minute)
# Find the largest 3 eigenvalues and their indices. Use these to get the corresponding eigenvectors.
# Plot these 3 eigenvectors after reshaping. These are the loadings of the top 3 principal components. What do these images represent?

# %%
XTX= X.T @ X
XTX.shape
# Out:
# (4096, 4096)

# %%
v, V=np.linalg.eig(XTX)
print(v, V)

# %% [markdown]
# Without trying to calculate it, will this matrix (X’X) be invertible? Why or why not?

# %% [markdown]
# added additional rows/columns so must have combinations

# %%
means
np.where(means == 0.4762809)
# Out:
# (array([2]),)
